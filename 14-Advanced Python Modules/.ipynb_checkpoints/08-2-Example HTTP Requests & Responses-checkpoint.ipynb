# %% [markdown]
# This notebook utilizes http://httpbin.org/ which implements a HTTP(S) server. Refer to its documentation.

# %% [markdown]
# # 1. HTTP Methods

# %% [markdown]
# ### 1.1 GET method

# %% [markdown]
# GET – Requesting resource from server

# %% [raw]
# curl -i -X GET "http://httpbin.org/get" -H  "accept: application/json"

# %% [markdown]
# results in the request:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# results in the response:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where the JSON object received is:

# %% [raw]
# {
#   "args": {},
#   "headers": {
#     "Accept": "application/json",
#     "Host": "httpbin.org",
#     "User-Agent": "curl/7.65.3"
#   },
#   "origin": "80.221.51.88, 80.221.51.88",
#   "url": "https://httpbin.org/get"
# }

# %% [markdown]
# ### 1.1 POST method

# %% [markdown]
# POST – submitting a resource to a server (e.g. file uploads)

# %% [raw]
# curl -i -X POST "http://httpbin.org/post" -H  "accept: application/json"

# %% [markdown]
# results in the request:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# results in the response:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where the obtained JSON object is:

# %% [raw]
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "application/json",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "curl/7.65.3"
#   },
#   "json": null,
#   "origin": "80.221.51.88, 80.221.51.88",
#   "url": "https://httpbin.org/post"
# }

# %% [markdown]
# ### 1.3 DELETE request

# %% [markdown]
# Delete a resource from a server

# %% [raw]
# curl -i -X DELETE "http://httpbin.org/delete" -H  "accept: application/json"

# %% [markdown]
# results in the following request:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# results in the following response:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.4 PATCH request

# %% [markdown]
# PATCH -Apply modifications to a resource

# %% [raw]
# curl -i -X PATCH "http://httpbin.org/patch" -H  "accept: application/json"

# %% [markdown]
# results in the following request:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# resulting in the following response:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.5 PUT Request

# %% [markdown]
# PUT -As POST but replaces an existing resource

# %% [raw]
# curl -i -X PUT "http://httpbin.org/put" -H  "accept: application/json"

# %% [markdown]
# which results in the following response:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# resulting in the following response:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.6 OPTIONS method

# %% [markdown]
# OPTIONS -To find out which request types a server supports, one can use curl and issue an OPTIONS request:

# %% [raw]
# curl -i -X OPTIONS "http://httpbin.org/"

# %% [markdown]
# which results in the following request:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# which results in the following response:

# %% [markdown]
# ![image.png](attachment:image.png)
